# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import sigpy as sp
import os
import nibabel as nib

plt.rcParams.update({'font.size': 18})
plt.rcParams["savefig.bbox"] = 'tight'

# %%
maxt1 = 2500
maxt2 = 250

# %% [markdown]
# # Load Data

# %%
case = "../data/testing/case000"
mp = 'T1'

target_T1_0 = np.load("%s/%s_ref_6min.npy" % (case,mp), mmap_mode="r")
uinit40_T1_0 = np.load("%s/%s_ref_2min.npy" % (case,mp), mmap_mode="r")
uinit35_T1_0 = np.load("%s/%s_uinit_2min_iters_35.npy" % (case,mp), mmap_mode="r")
uinit30_T1_0 = np.load("%s/%s_uinit_2min_iters_30.npy" % (case,mp), mmap_mode="r")
uinit25_T1_0 = np.load("%s/%s_uinit_2min_iters_25.npy" % (case,mp), mmap_mode="r")
uinit20_T1_0 = np.load("%s/%s_uinit_2min_iters_20.npy" % (case,mp), mmap_mode="r")
uinit15_T1_0 = np.load("%s/%s_uinit_2min_iters_15.npy" % (case,mp), mmap_mode="r")
uinit12_T1_0 = np.load("%s/%s_uinit_2min_iters_12.npy" % (case,mp), mmap_mode="r")
uinit10_T1_0 = np.load("%s/%s_uinit_2min_iters_10.npy" % (case,mp), mmap_mode="r")
uinit8_T1_0 = np.load("%s/%s_uinit_2min_iters_8.npy" % (case,mp), mmap_mode="r")
uinit6_T1_0 = np.load("%s/%s_uinit_2min_iters_6.npy" % (case,mp), mmap_mode="r")
uinit4_T1_0 = np.load("%s/%s_uinit_2min_iters_4.npy" % (case,mp), mmap_mode="r")

init40_T1_0 = np.load("%s/%s_refine_2min_iters_40.npy" % (case,mp), mmap_mode="r")
init35_T1_0 = np.load("%s/%s_refine_2min_iters_35.npy" % (case,mp), mmap_mode="r")
init30_T1_0 = np.load("%s/%s_refine_2min_iters_30.npy" % (case,mp), mmap_mode="r")
init25_T1_0 = np.load("%s/%s_refine_2min_iters_25.npy" % (case,mp), mmap_mode="r")
init20_T1_0 = np.load("%s/%s_refine_2min_iters_20.npy" % (case,mp), mmap_mode="r")
init15_T1_0 = np.load("%s/%s_refine_2min_iters_15.npy" % (case,mp), mmap_mode="r")
init12_T1_0 = np.load("%s/%s_refine_2min_iters_12.npy" % (case,mp), mmap_mode="r")
init10_T1_0 = np.load("%s/%s_refine_2min_iters_10.npy" % (case,mp), mmap_mode="r")
init8_T1_0 = np.load("%s/%s_refine_2min_iters_8.npy" % (case,mp), mmap_mode="r")
init6_T1_0 = np.load("%s/%s_refine_2min_iters_6.npy" % (case,mp), mmap_mode="r")
init4_T1_0 = np.load("%s/%s_refine_2min_iters_4.npy" % (case,mp), mmap_mode="r")

# %%
case = "../data/testing/case000"
mp = 'T2'

target_T2_0 = np.load("%s/%s_ref_6min.npy" % (case,mp), mmap_mode="r")
uinit40_T2_0 = np.load("%s/%s_ref_2min.npy" % (case,mp), mmap_mode="r")
uinit35_T2_0 = np.load("%s/%s_uinit_2min_iters_35.npy" % (case,mp), mmap_mode="r")
uinit30_T2_0 = np.load("%s/%s_uinit_2min_iters_30.npy" % (case,mp), mmap_mode="r")
uinit25_T2_0 = np.load("%s/%s_uinit_2min_iters_25.npy" % (case,mp), mmap_mode="r")
uinit20_T2_0 = np.load("%s/%s_uinit_2min_iters_20.npy" % (case,mp), mmap_mode="r")
uinit15_T2_0 = np.load("%s/%s_uinit_2min_iters_15.npy" % (case,mp), mmap_mode="r")
uinit12_T2_0 = np.load("%s/%s_uinit_2min_iters_12.npy" % (case,mp), mmap_mode="r")
uinit10_T2_0 = np.load("%s/%s_uinit_2min_iters_10.npy" % (case,mp), mmap_mode="r")
uinit8_T2_0 = np.load("%s/%s_uinit_2min_iters_8.npy" % (case,mp), mmap_mode="r")
uinit6_T2_0 = np.load("%s/%s_uinit_2min_iters_6.npy" % (case,mp), mmap_mode="r")
uinit4_T2_0 = np.load("%s/%s_uinit_2min_iters_4.npy" % (case,mp), mmap_mode="r")

init40_T2_0 = np.load("%s/%s_refine_2min_iters_40.npy" % (case,mp), mmap_mode="r")
init35_T2_0 = np.load("%s/%s_refine_2min_iters_35.npy" % (case,mp), mmap_mode="r")
init30_T2_0 = np.load("%s/%s_refine_2min_iters_30.npy" % (case,mp), mmap_mode="r")
init25_T2_0 = np.load("%s/%s_refine_2min_iters_25.npy" % (case,mp), mmap_mode="r")
init20_T2_0 = np.load("%s/%s_refine_2min_iters_20.npy" % (case,mp), mmap_mode="r")
init15_T2_0 = np.load("%s/%s_refine_2min_iters_15.npy" % (case,mp), mmap_mode="r")
init12_T2_0 = np.load("%s/%s_refine_2min_iters_12.npy" % (case,mp), mmap_mode="r")
init10_T2_0 = np.load("%s/%s_refine_2min_iters_10.npy" % (case,mp), mmap_mode="r")
init8_T2_0 = np.load("%s/%s_refine_2min_iters_8.npy" % (case,mp), mmap_mode="r")
init6_T2_0 = np.load("%s/%s_refine_2min_iters_6.npy" % (case,mp), mmap_mode="r")
init4_T2_0 = np.load("%s/%s_refine_2min_iters_4.npy" % (case,mp), mmap_mode="r")

# %%
case = "../data/testing/case001"
mp = 'T1'

target_T1_1 = np.load("%s/%s_ref_6min.npy" % (case,mp), mmap_mode="r")
uinit40_T1_1 = np.load("%s/%s_ref_2min.npy" % (case,mp), mmap_mode="r")
uinit35_T1_1 = np.load("%s/%s_uinit_2min_iters_35.npy" % (case,mp), mmap_mode="r")
uinit30_T1_1 = np.load("%s/%s_uinit_2min_iters_30.npy" % (case,mp), mmap_mode="r")
uinit25_T1_1 = np.load("%s/%s_uinit_2min_iters_25.npy" % (case,mp), mmap_mode="r")
uinit20_T1_1 = np.load("%s/%s_uinit_2min_iters_20.npy" % (case,mp), mmap_mode="r")
uinit15_T1_1 = np.load("%s/%s_uinit_2min_iters_15.npy" % (case,mp), mmap_mode="r")
uinit12_T1_1 = np.load("%s/%s_uinit_2min_iters_12.npy" % (case,mp), mmap_mode="r")
uinit10_T1_1 = np.load("%s/%s_uinit_2min_iters_10.npy" % (case,mp), mmap_mode="r")
uinit8_T1_1 = np.load("%s/%s_uinit_2min_iters_8.npy" % (case,mp), mmap_mode="r")
uinit6_T1_1 = np.load("%s/%s_uinit_2min_iters_6.npy" % (case,mp), mmap_mode="r")
uinit4_T1_1 = np.load("%s/%s_uinit_2min_iters_4.npy" % (case,mp), mmap_mode="r")

init40_T1_1 = np.load("%s/%s_refine_2min_iters_40.npy" % (case,mp), mmap_mode="r")
init35_T1_1 = np.load("%s/%s_refine_2min_iters_35.npy" % (case,mp), mmap_mode="r")
init30_T1_1 = np.load("%s/%s_refine_2min_iters_30.npy" % (case,mp), mmap_mode="r")
init25_T1_1 = np.load("%s/%s_refine_2min_iters_25.npy" % (case,mp), mmap_mode="r")
init20_T1_1 = np.load("%s/%s_refine_2min_iters_20.npy" % (case,mp), mmap_mode="r")
init15_T1_1 = np.load("%s/%s_refine_2min_iters_15.npy" % (case,mp), mmap_mode="r")
init12_T1_1 = np.load("%s/%s_refine_2min_iters_12.npy" % (case,mp), mmap_mode="r")
init10_T1_1 = np.load("%s/%s_refine_2min_iters_10.npy" % (case,mp), mmap_mode="r")
init8_T1_1 = np.load("%s/%s_refine_2min_iters_8.npy" % (case,mp), mmap_mode="r")
init6_T1_1 = np.load("%s/%s_refine_2min_iters_6.npy" % (case,mp), mmap_mode="r")
init4_T1_1 = np.load("%s/%s_refine_2min_iters_4.npy" % (case,mp), mmap_mode="r")

# %%
case = "../data/testing/case001"
mp = 'T2'

target_T2_1 = np.load("%s/%s_ref_6min.npy" % (case,mp), mmap_mode="r")
uinit40_T2_1 = np.load("%s/%s_ref_2min.npy" % (case,mp), mmap_mode="r")
uinit35_T2_1 = np.load("%s/%s_uinit_2min_iters_35.npy" % (case,mp), mmap_mode="r")
uinit30_T2_1 = np.load("%s/%s_uinit_2min_iters_30.npy" % (case,mp), mmap_mode="r")
uinit25_T2_1 = np.load("%s/%s_uinit_2min_iters_25.npy" % (case,mp), mmap_mode="r")
uinit20_T2_1 = np.load("%s/%s_uinit_2min_iters_20.npy" % (case,mp), mmap_mode="r")
uinit15_T2_1 = np.load("%s/%s_uinit_2min_iters_15.npy" % (case,mp), mmap_mode="r")
uinit12_T2_1 = np.load("%s/%s_uinit_2min_iters_12.npy" % (case,mp), mmap_mode="r")
uinit10_T2_1 = np.load("%s/%s_uinit_2min_iters_10.npy" % (case,mp), mmap_mode="r")
uinit8_T2_1 = np.load("%s/%s_uinit_2min_iters_8.npy" % (case,mp), mmap_mode="r")
uinit6_T2_1 = np.load("%s/%s_uinit_2min_iters_6.npy" % (case,mp), mmap_mode="r")
uinit4_T2_1 = np.load("%s/%s_uinit_2min_iters_4.npy" % (case,mp), mmap_mode="r")

init40_T2_1 = np.load("%s/%s_refine_2min_iters_40.npy" % (case,mp), mmap_mode="r")
init35_T2_1 = np.load("%s/%s_refine_2min_iters_35.npy" % (case,mp), mmap_mode="r")
init30_T2_1 = np.load("%s/%s_refine_2min_iters_30.npy" % (case,mp), mmap_mode="r")
init25_T2_1 = np.load("%s/%s_refine_2min_iters_25.npy" % (case,mp), mmap_mode="r")
init20_T2_1 = np.load("%s/%s_refine_2min_iters_20.npy" % (case,mp), mmap_mode="r")
init15_T2_1 = np.load("%s/%s_refine_2min_iters_15.npy" % (case,mp), mmap_mode="r")
init12_T2_1 = np.load("%s/%s_refine_2min_iters_12.npy" % (case,mp), mmap_mode="r")
init10_T2_1 = np.load("%s/%s_refine_2min_iters_10.npy" % (case,mp), mmap_mode="r")
init8_T2_1 = np.load("%s/%s_refine_2min_iters_8.npy" % (case,mp), mmap_mode="r")
init6_T2_1 = np.load("%s/%s_refine_2min_iters_6.npy" % (case,mp), mmap_mode="r")
init4_T2_1 = np.load("%s/%s_refine_2min_iters_4.npy" % (case,mp), mmap_mode="r")

# %% [markdown]
# # Create/Load Masks

# %%
case = "../data/testing/case000"
mp = 'T1'
# Requires FSL installation
if not os.path.isfile(f'{case}/{mp}_ref_6min_msk_pve_2.nii.gz'):
    os.environ['FSLDIR'] = '/usr/local/fsl'
    here = os.getcwd()
    nib.save(nib.Nifti1Image(target_T1_0, np.eye(4)),f'{here}/{case}/{mp}_ref_6min.nii.gz')
    os.system(f"/usr/local/fsl/bin/bet {here}/{case}/{mp}_ref_6min {here}/{case}/{mp}_ref_6min_msk  -m -g -0.5 -f 0.9")
    brain_mask_0 = nib.load(f'{here}/{case}/{mp}_ref_6min_msk_mask.nii.gz').get_fdata()
    brain_mask_0 = np.array(brain_mask_0,dtype=int)
    os.system(f'/usr/local/fsl/bin/fast {here}/{case}/{mp}_ref_6min_msk.nii.gz ' )

wm_seg_mask_0 = nib.load(f'{case}/{mp}_ref_6min_msk_pve_0.nii.gz').get_fdata()
gm_seg_mask_0 = nib.load(f'{case}/{mp}_ref_6min_msk_pve_1.nii.gz').get_fdata()
csf_seg_mask_0 = nib.load(f'{case}/{mp}_ref_6min_msk_pve_2.nii.gz').get_fdata()

wmgm_mask_0 = np.zeros(wm_seg_mask_0.shape,dtype=bool)
wmgm_mask_0[wm_seg_mask_0!=0]=True
wmgm_mask_0[gm_seg_mask_0!=0]=True
wmgm_mask_0[csf_seg_mask_0!=0]=False
wmgm_mask_0[target_T1_0>2000]=False
wmgm_mask_0[target_T1_0<500]=False
wmgm_mask_0[target_T2_0>400]=False
wmgm_mask_0[target_T2_0<40]=False

# %%
case = "../data/testing/case001"
mp = 'T1'
# Requires FSL installation
if not os.path.isfile(f'{case}/{mp}_ref_6min_msk_pve_2.nii.gz'):
    os.environ['FSLDIR'] = '/usr/local/fsl'
    here = os.getcwd()
    nib.save(nib.Nifti1Image(target_T1_1, np.eye(4)),f'{here}/{case}/{mp}_ref_6min.nii.gz')
    os.system(f"/usr/local/fsl/bin/bet {here}/{case}/{mp}_ref_6min {here}/{case}/{mp}_ref_6min_msk  -m -g -0.5 -f 0.9")
    brain_mask_1 = nib.load(f'{here}/{case}/{mp}_ref_6min_msk_mask.nii.gz').get_fdata()
    brain_mask_1 = np.array(brain_mask_0,dtype=int)
    os.system(f'/usr/local/fsl/bin/fast {here}/{case}/{mp}_ref_6min_msk.nii.gz ' )

wm_seg_mask_1 = nib.load(f'{case}/{mp}_ref_6min_msk_pve_0.nii.gz').get_fdata()
gm_seg_mask_1 = nib.load(f'{case}/{mp}_ref_6min_msk_pve_1.nii.gz').get_fdata()
csf_seg_mask_1 = nib.load(f'{case}/{mp}_ref_6min_msk_pve_2.nii.gz').get_fdata()

wmgm_mask_1 = np.zeros(wm_seg_mask_1.shape,dtype=bool)
wmgm_mask_1[wm_seg_mask_1!=0]=True
wmgm_mask_1[gm_seg_mask_1!=0]=True
wmgm_mask_1[csf_seg_mask_1!=0]=False
wmgm_mask_1[target_T1_1>2000]=False
wmgm_mask_1[target_T1_1<500]=False
wmgm_mask_1[target_T2_1>400]=False
wmgm_mask_1[target_T2_1<40]=False

# %% [markdown]
# # Calculate Error

# %%
def rmse(im,GT):
    out = (np.sqrt(np.mean((np.abs((im.ravel())-(GT.ravel())))**2)))
    
    return out

# %%
T1_err_u40 = rmse(uinit40_T1_0[wmgm_mask_0],target_T1_0[wmgm_mask_0])
T1_err_u35= rmse(uinit35_T1_0[wmgm_mask_0],target_T1_0[wmgm_mask_0])
T1_err_u30= rmse(uinit30_T1_0[wmgm_mask_0],target_T1_0[wmgm_mask_0])
T1_err_u25= rmse(uinit25_T1_0[wmgm_mask_0],target_T1_0[wmgm_mask_0])
T1_err_u20= rmse(uinit20_T1_0[wmgm_mask_0],target_T1_0[wmgm_mask_0])
T1_err_u15= rmse(uinit15_T1_0[wmgm_mask_0],target_T1_0[wmgm_mask_0])
T1_err_u12= rmse(uinit12_T1_0[wmgm_mask_0],target_T1_0[wmgm_mask_0])
T1_err_u10 = rmse(uinit10_T1_0[wmgm_mask_0],target_T1_0[wmgm_mask_0])
T1_err_u8 = rmse(uinit8_T1_0[wmgm_mask_0],target_T1_0[wmgm_mask_0])
T1_err_u6 = rmse(uinit6_T1_0[wmgm_mask_0],target_T1_0[wmgm_mask_0])
T1_err_u4 = rmse(uinit4_T1_0[wmgm_mask_0],target_T1_0[wmgm_mask_0])

T1_err_i40 = rmse(init40_T1_0[wmgm_mask_0],target_T1_0[wmgm_mask_0])
T1_err_i35= rmse(init35_T1_0[wmgm_mask_0],target_T1_0[wmgm_mask_0])
T1_err_i30= rmse(init30_T1_0[wmgm_mask_0],target_T1_0[wmgm_mask_0])
T1_err_i25= rmse(init25_T1_0[wmgm_mask_0],target_T1_0[wmgm_mask_0])
T1_err_i20= rmse(init20_T1_0[wmgm_mask_0],target_T1_0[wmgm_mask_0])
T1_err_i15= rmse(init15_T1_0[wmgm_mask_0],target_T1_0[wmgm_mask_0])
T1_err_i12= rmse(init12_T1_0[wmgm_mask_0],target_T1_0[wmgm_mask_0])
T1_err_i10 = rmse(init10_T1_0[wmgm_mask_0],target_T1_0[wmgm_mask_0])
T1_err_i8 = rmse(init8_T1_0[wmgm_mask_0],target_T1_0[wmgm_mask_0])
T1_err_i6 = rmse(init6_T1_0[wmgm_mask_0],target_T1_0[wmgm_mask_0])
T1_err_i4 = rmse(init4_T1_0[wmgm_mask_0],target_T1_0[wmgm_mask_0])

# %%
T1_err_u40 = [T1_err_u40,  rmse(uinit40_T1_1[wmgm_mask_1],target_T1_1[wmgm_mask_1])]
T1_err_u35 = [T1_err_u35, rmse(uinit35_T1_1[wmgm_mask_1],target_T1_1[wmgm_mask_1])]
T1_err_u30 = [T1_err_u30, rmse(uinit30_T1_1[wmgm_mask_1],target_T1_1[wmgm_mask_1])]
T1_err_u25 = [T1_err_u25, rmse(uinit25_T1_1[wmgm_mask_1],target_T1_1[wmgm_mask_1])]
T1_err_u20 = [T1_err_u20, rmse(uinit20_T1_1[wmgm_mask_1],target_T1_1[wmgm_mask_1])]
T1_err_u15 = [T1_err_u15, rmse(uinit15_T1_1[wmgm_mask_1],target_T1_1[wmgm_mask_1])]
T1_err_u12 = [T1_err_u12, rmse(uinit12_T1_1[wmgm_mask_1],target_T1_1[wmgm_mask_1])]
T1_err_u10 = [T1_err_u10,  rmse(uinit10_T1_1[wmgm_mask_1],target_T1_1[wmgm_mask_1])]
T1_err_u8 = [T1_err_u8,  rmse(uinit8_T1_1[wmgm_mask_1],target_T1_1[wmgm_mask_1])]
T1_err_u6 = [T1_err_u6,  rmse(uinit6_T1_1[wmgm_mask_1],target_T1_1[wmgm_mask_1])]
T1_err_u4 = [T1_err_u4,  rmse(uinit4_T1_1[wmgm_mask_1],target_T1_1[wmgm_mask_1])]

T1_err_i40 = [T1_err_i40,  rmse(init40_T1_1[wmgm_mask_1],target_T1_1[wmgm_mask_1])]
T1_err_i35 = [T1_err_i35, rmse(init35_T1_1[wmgm_mask_1],target_T1_1[wmgm_mask_1])]
T1_err_i30 = [T1_err_i30, rmse(init30_T1_1[wmgm_mask_1],target_T1_1[wmgm_mask_1])]
T1_err_i25 = [T1_err_i25, rmse(init25_T1_1[wmgm_mask_1],target_T1_1[wmgm_mask_1])]
T1_err_i20 = [T1_err_i20, rmse(init20_T1_1[wmgm_mask_1],target_T1_1[wmgm_mask_1])]
T1_err_i15 = [T1_err_i15, rmse(init15_T1_1[wmgm_mask_1],target_T1_1[wmgm_mask_1])]
T1_err_i12 = [T1_err_i12, rmse(init12_T1_1[wmgm_mask_1],target_T1_1[wmgm_mask_1])]
T1_err_i10 = [T1_err_i10,  rmse(init10_T1_1[wmgm_mask_1],target_T1_1[wmgm_mask_1])]
T1_err_i8 = [T1_err_i8,  rmse(init8_T1_1[wmgm_mask_1],target_T1_1[wmgm_mask_1])]
T1_err_i6 = [T1_err_i6,  rmse(init6_T1_1[wmgm_mask_1],target_T1_1[wmgm_mask_1])]
T1_err_i4 = [T1_err_i4,  rmse(init4_T1_1[wmgm_mask_1],target_T1_1[wmgm_mask_1])]

# %%
T2_err_u40 = rmse(uinit40_T2_0[wmgm_mask_0],target_T2_0[wmgm_mask_0])
T2_err_u35= rmse(uinit35_T2_0[wmgm_mask_0],target_T2_0[wmgm_mask_0])
T2_err_u30= rmse(uinit30_T2_0[wmgm_mask_0],target_T2_0[wmgm_mask_0])
T2_err_u25= rmse(uinit25_T2_0[wmgm_mask_0],target_T2_0[wmgm_mask_0])
T2_err_u20= rmse(uinit20_T2_0[wmgm_mask_0],target_T2_0[wmgm_mask_0])
T2_err_u15= rmse(uinit15_T2_0[wmgm_mask_0],target_T2_0[wmgm_mask_0])
T2_err_u12= rmse(uinit12_T2_0[wmgm_mask_0],target_T2_0[wmgm_mask_0])
T2_err_u10 = rmse(uinit10_T2_0[wmgm_mask_0],target_T2_0[wmgm_mask_0])
T2_err_u8 = rmse(uinit8_T2_0[wmgm_mask_0],target_T2_0[wmgm_mask_0])
T2_err_u6 = rmse(uinit6_T2_0[wmgm_mask_0],target_T2_0[wmgm_mask_0])
T2_err_u4 = rmse(uinit4_T2_0[wmgm_mask_0],target_T2_0[wmgm_mask_0])

T2_err_i40 = rmse(init40_T2_0[wmgm_mask_0],target_T2_0[wmgm_mask_0])
T2_err_i35= rmse(init35_T2_0[wmgm_mask_0],target_T2_0[wmgm_mask_0])
T2_err_i30= rmse(init30_T2_0[wmgm_mask_0],target_T2_0[wmgm_mask_0])
T2_err_i25= rmse(init25_T2_0[wmgm_mask_0],target_T2_0[wmgm_mask_0])
T2_err_i20= rmse(init20_T2_0[wmgm_mask_0],target_T2_0[wmgm_mask_0])
T2_err_i15= rmse(init15_T2_0[wmgm_mask_0],target_T2_0[wmgm_mask_0])
T2_err_i12= rmse(init12_T2_0[wmgm_mask_0],target_T2_0[wmgm_mask_0])
T2_err_i10 = rmse(init10_T2_0[wmgm_mask_0],target_T2_0[wmgm_mask_0])
T2_err_i8 = rmse(init8_T2_0[wmgm_mask_0],target_T2_0[wmgm_mask_0])
T2_err_i6 = rmse(init6_T2_0[wmgm_mask_0],target_T2_0[wmgm_mask_0])
T2_err_i4 = rmse(init4_T2_0[wmgm_mask_0],target_T2_0[wmgm_mask_0])

# %%
T2_err_u40 = [T2_err_u40,  rmse(uinit40_T2_1[wmgm_mask_1],target_T2_1[wmgm_mask_1])]
T2_err_u35 = [T2_err_u35, rmse(uinit35_T2_1[wmgm_mask_1],target_T2_1[wmgm_mask_1])]
T2_err_u30 = [T2_err_u30, rmse(uinit30_T2_1[wmgm_mask_1],target_T2_1[wmgm_mask_1])]
T2_err_u25 = [T2_err_u25, rmse(uinit25_T2_1[wmgm_mask_1],target_T2_1[wmgm_mask_1])]
T2_err_u20 = [T2_err_u20, rmse(uinit20_T2_1[wmgm_mask_1],target_T2_1[wmgm_mask_1])]
T2_err_u15 = [T2_err_u15, rmse(uinit15_T2_1[wmgm_mask_1],target_T2_1[wmgm_mask_1])]
T2_err_u12 = [T2_err_u12, rmse(uinit12_T2_1[wmgm_mask_1],target_T2_1[wmgm_mask_1])]
T2_err_u10 = [T2_err_u10,  rmse(uinit10_T2_1[wmgm_mask_1],target_T2_1[wmgm_mask_1])]
T2_err_u8 = [T2_err_u8,  rmse(uinit8_T2_1[wmgm_mask_1],target_T2_1[wmgm_mask_1])]
T2_err_u6 = [T2_err_u6,  rmse(uinit6_T2_1[wmgm_mask_1],target_T2_1[wmgm_mask_1])]
T2_err_u4 = [T2_err_u4,  rmse(uinit4_T2_1[wmgm_mask_1],target_T2_1[wmgm_mask_1])]

T2_err_i40 = [T2_err_i40, rmse(init40_T2_1[wmgm_mask_1],target_T2_1[wmgm_mask_1])]
T2_err_i35 = [T2_err_i35, rmse(init35_T2_1[wmgm_mask_1],target_T2_1[wmgm_mask_1])]
T2_err_i30 = [T2_err_i30, rmse(init30_T2_1[wmgm_mask_1],target_T2_1[wmgm_mask_1])]
T2_err_i25 = [T2_err_i25, rmse(init25_T2_1[wmgm_mask_1],target_T2_1[wmgm_mask_1])]
T2_err_i20 = [T2_err_i20, rmse(init20_T2_1[wmgm_mask_1],target_T2_1[wmgm_mask_1])]
T2_err_i15 = [T2_err_i15, rmse(init15_T2_1[wmgm_mask_1],target_T2_1[wmgm_mask_1])]
T2_err_i12 = [T2_err_i12, rmse(init12_T2_1[wmgm_mask_1],target_T2_1[wmgm_mask_1])]
T2_err_i10 = [T2_err_i10,  rmse(init10_T2_1[wmgm_mask_1],target_T2_1[wmgm_mask_1])]
T2_err_i8 = [T2_err_i8,  rmse(init8_T2_1[wmgm_mask_1],target_T2_1[wmgm_mask_1])]
T2_err_i6 = [T2_err_i6,  rmse(init6_T2_1[wmgm_mask_1],target_T2_1[wmgm_mask_1])]
T2_err_i4 = [T2_err_i4,  rmse(init4_T2_1[wmgm_mask_1],target_T2_1[wmgm_mask_1])]

# %% [markdown]
# # Plot

# %%
idx = [slice(None), 128, slice(None, None, -1)]

with plt.rc_context({'axes.prop_cycle': plt.cycler(color=['red', 'blue'])}):
   plt.cycler(color=['red', 'blue'])
   fig, axs = plt.subplots(2, 2, figsize=(15, 15),dpi=300,layout='tight')

   axs[0][0].plot([4,6,8,10,12,15,20,25,30,35,40],[T1_err_u4,T1_err_u6,T1_err_u8,T1_err_u10,T1_err_u12,T1_err_u15,T1_err_u20,T1_err_u25,T1_err_u30,T1_err_u35,T1_err_u40],marker='x',linewidth=2)
   axs[0][0].plot([4,6,8,10,12,15,20,25,30,35,40],[T1_err_i4,T1_err_i6,T1_err_i8,T1_err_i10,T1_err_i12,T1_err_i15,T1_err_i20,T1_err_i25,T1_err_i30,T1_err_i35,T1_err_i40],marker='o',linewidth=2,linestyle='--')
   axs[0][0].legend(('initialized with $A^*b$ (Subj 1)','initialized with $A^*b$ (Subj 2)', 'initialized with DeliCS (Subj 1)','initialized with DeliCS (Subj 2)'))
   axs[0][0].set_ylabel('RMSE (ms)')
   axs[0][0].set_xlabel('iterations')
   axs[0][0].set_title('(A)\nT1 error')
   axs[0][0].grid('minor',alpha=0.1)

   axs[0][1].plot([4,6,8,10,12,15,20,25,30,35,40],[T2_err_u4,T2_err_u6,T2_err_u8,T2_err_u10,T2_err_u12,T2_err_u15,T2_err_u20,T2_err_u25,T2_err_u30,T2_err_u35,T2_err_u40],marker='x',linewidth=2)
   axs[0][1].plot([4,6,8,10,12,15,20,25,30,35,40],[T2_err_i4,T2_err_i6,T2_err_i8,T2_err_i10,T2_err_i12,T2_err_i15,T2_err_i20,T2_err_i25,T2_err_i30,T2_err_i35,T2_err_i40],marker='o',linewidth=2,linestyle='--')
   axs[0][1].legend(('initialized with A^*b (Subj 1)','initialized with $A^*b$ (Subj 2)', 'initialized with DeliCS (Subj 1)','initialized with DeliCS (Subj 2)'))
   axs[0][1].set_ylabel('RMSE (ms)')
   axs[0][1].set_xlabel('iterations')
   axs[0][1].set_title('(C)\nT2 error')
   axs[0][1].grid('minor',alpha=0.1)



im = axs[1][0].imshow(np.concatenate((-np.concatenate(\
                                    ( (np.rot90(((target_T1_0))[128,:,::-1],k=-1)-np.rot90(((init4_T1_0))[128,:,::-1],k=-1)), \
                                     (np.rot90(((target_T1_0))[128,:,::-1],k=-1)-np.rot90(((uinit4_T1_0))[128,:,::-1],k=-1))),axis=0),\
                                     -np.concatenate(\
                                    ( (np.rot90(((target_T1_0))[128,:,::-1],k=-1)-np.rot90(((init20_T1_0))[128,:,::-1],k=-1)), \
                                     (np.rot90(((target_T1_0))[128,:,::-1],k=-1)-np.rot90(((uinit20_T1_0))[128,:,::-1],k=-1))),axis=0),\
                                     -np.concatenate(\
                                    ( (np.rot90(((target_T1_0))[128,:,::-1],k=-1)-np.rot90(((init40_T1_0))[128,:,::-1],k=-1)), \
                                     (np.rot90(((target_T1_0))[128,:,::-1],k=-1)-np.rot90(((uinit40_T1_0))[128,:,::-1],k=-1))),axis=0)),axis=1)
                                        , cmap="bwr", vmin=-150,vmax=150)

axs[1][0].imshow(np.ma.masked_array(np.concatenate((np.concatenate(\
                                    ( (np.rot90(((wmgm_mask_0))[128,:,::-1],k=-1)), \
                                     (np.rot90(((wmgm_mask_0))[128,:,::-1],k=-1))),axis=0),\
                                     np.concatenate(\
                                    ( (np.rot90(((wmgm_mask_0))[128,:,::-1],k=-1)), \
                                     (np.rot90(((wmgm_mask_0))[128,:,::-1],k=-1))),axis=0),
                                     np.concatenate(\
                                    ( (np.rot90(((wmgm_mask_0))[128,:,::-1],k=-1)), \
                                     (np.rot90(((wmgm_mask_0))[128,:,::-1],k=-1))),axis=0)),axis=1),\
                                       mask = np.concatenate((np.concatenate(\
                                    ( (np.rot90(((wmgm_mask_0))[128,:,::-1],k=-1)), \
                                     (np.rot90(((wmgm_mask_0))[128,:,::-1],k=-1))),axis=0),\
                                     np.concatenate(\
                                    ( (np.rot90(((wmgm_mask_0))[128,:,::-1],k=-1)), \
                                     (np.rot90(((wmgm_mask_0))[128,:,::-1],k=-1))),axis=0),
                                     np.concatenate(\
                                    ( (np.rot90(((wmgm_mask_0))[128,:,::-1],k=-1)), \
                                     (np.rot90(((wmgm_mask_0))[128,:,::-1],k=-1))),axis=0)),axis=1))\
                                        , cmap="gray", vmin=0,vmax=1)

plt.colorbar(im, ax=axs[1][0],shrink=0.5,label='ms',orientation='horizontal')
axs[1][0].set_yticks([128,128+256])
axs[1][0].set_yticklabels(["Initialized\n with DeliCS",'Initialized\n with $A^*b$'],rotation=45,va='top',ha='right',fontsize=14)
axs[1][0].set_xticks([128,128+256,128+256+256])
axs[1][0].set_xticklabels(["4 iterations",'20 iterations', '40 iterations'],va='top',ha='center')
axs[1][0].set_title('(D)\nT1 error (Subj 1)')
axs[1][0].text(30, 220, f'RMSE={T1_err_i4[0]:.3g}', bbox=dict(fill=False, edgecolor='red', linewidth=2),color='w')
axs[1][0].text(30, 490, f'RMSE={T1_err_u4[0]:.3g}', bbox=dict(fill=False, edgecolor='red', linewidth=2),color='w')
axs[1][0].text(30+256, 220, f'RMSE={T1_err_i20[0]:.3g}', bbox=dict(fill=False, edgecolor='red', linewidth=2),color='w')
axs[1][0].text(30+256, 490, f'RMSE={T1_err_u20[0]:.3g}', bbox=dict(fill=False, edgecolor='red', linewidth=2),color='w')
axs[1][0].text(30+512, 220, f'RMSE={T1_err_i40[0]:.3g}', bbox=dict(fill=False, edgecolor='red', linewidth=2),color='w')
axs[1][0].text(30+512, 490, f'RMSE={T1_err_u40[0]:.3g}', bbox=dict(fill=False, edgecolor='red', linewidth=2),color='w')


im = axs[1][1].imshow(np.concatenate((-np.concatenate(\
                                    ( (np.rot90(((target_T2_0))[128,:,::-1],k=-1)-np.rot90(((init4_T2_0))[128,:,::-1],k=-1)), \
                                     (np.rot90(((target_T2_0))[128,:,::-1],k=-1)-np.rot90(((uinit4_T2_0))[128,:,::-1],k=-1))),axis=0),\
                                     -np.concatenate(\
                                    ( (np.rot90(((target_T2_0))[128,:,::-1],k=-1)-np.rot90(((init20_T2_0))[128,:,::-1],k=-1)), \
                                     (np.rot90(((target_T2_0))[128,:,::-1],k=-1)-np.rot90(((uinit20_T2_0))[128,:,::-1],k=-1))),axis=0),\
                                     -np.concatenate(\
                                    ( (np.rot90(((target_T2_0))[128,:,::-1],k=-1)-np.rot90(((init40_T2_0))[128,:,::-1],k=-1)), \
                                     (np.rot90(((target_T2_0))[128,:,::-1],k=-1)-np.rot90(((uinit40_T2_0))[128,:,::-1],k=-1))),axis=0)),axis=1)
                                        , cmap="bwr", vmin=-15,vmax=15)

axs[1][1].imshow(np.ma.masked_array(np.concatenate((np.concatenate(\
                                    ( (np.rot90(((wmgm_mask_0))[128,:,::-1],k=-1)), \
                                     (np.rot90(((wmgm_mask_0))[128,:,::-1],k=-1))),axis=0),\
                                     np.concatenate(\
                                    ( (np.rot90(((wmgm_mask_0))[128,:,::-1],k=-1)), \
                                     (np.rot90(((wmgm_mask_0))[128,:,::-1],k=-1))),axis=0),
                                     np.concatenate(\
                                    ( (np.rot90(((wmgm_mask_0))[128,:,::-1],k=-1)), \
                                     (np.rot90(((wmgm_mask_0))[128,:,::-1],k=-1))),axis=0)),axis=1),\
                                       mask = np.concatenate((np.concatenate(\
                                    ( (np.rot90(((wmgm_mask_0))[128,:,::-1],k=-1)), \
                                     (np.rot90(((wmgm_mask_0))[128,:,::-1],k=-1))),axis=0),\
                                     np.concatenate(\
                                    ( (np.rot90(((wmgm_mask_0))[128,:,::-1],k=-1)), \
                                     (np.rot90(((wmgm_mask_0))[128,:,::-1],k=-1))),axis=0),
                                     np.concatenate(\
                                    ( (np.rot90(((wmgm_mask_0))[128,:,::-1],k=-1)), \
                                     (np.rot90(((wmgm_mask_0))[128,:,::-1],k=-1))),axis=0)),axis=1))\
                                        , cmap="gray", vmin=0,vmax=1)

                                        
plt.colorbar(im, ax=axs[1][1],shrink=0.5,label='ms',orientation='horizontal')
axs[1][1].set_yticks([128,128+256])
axs[1][1].set_yticklabels(["Initialized\n with DeliCS",'Initialized\n with $A^*b$'],rotation=45,va='top',ha='right',fontsize=14)
axs[1][1].set_xticks([128,128+256,128+256+256])
axs[1][1].set_xticklabels(["4 iterations",'20 iterations', '40 iterations'],va='top',ha='center')
axs[1][1].set_title('(D)\nT2 error (Subj 1)')
axs[1][1].text(30, 220, f'RMSE={T2_err_i4[0]:.3g}', bbox=dict(fill=False, edgecolor='red', linewidth=2),color='w')
axs[1][1].text(30, 490, f'RMSE={T2_err_u4[0]:.3g}', bbox=dict(fill=False, edgecolor='red', linewidth=2),color='w')
axs[1][1].text(30+256, 220, f'RMSE={T2_err_i20[0]:.3g}', bbox=dict(fill=False, edgecolor='red', linewidth=2),color='w')
axs[1][1].text(30+256, 490, f'RMSE={T2_err_u20[0]:.3g}', bbox=dict(fill=False, edgecolor='red', linewidth=2),color='w')
axs[1][1].text(30+512, 220, f'RMSE={T2_err_i40[0]:.3g}', bbox=dict(fill=False, edgecolor='red', linewidth=2),color='w')
axs[1][1].text(30+512, 490, f'RMSE={T2_err_u40[0]:.3g}', bbox=dict(fill=False, edgecolor='red', linewidth=2),color='w')
# Out:
# Text(542, 490, 'RMSE=30.4')
